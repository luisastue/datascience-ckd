# %% [markdown]
# ### 6.1a Evaluation Feature Importance without diabetes

# %%
import pandas as pd
import numpy as np

# %%
feature_importances = {
    'random_forest': pd.read_csv('results/feature_importances_random_forest_without_diabetes.csv', index_col=0),
    'gradient_boosting': pd.read_csv('results/feature_importances_gradient_boosting_without_diabetes.csv', index_col=0),
    'logistic_regression': pd.read_csv('results/feature_importances_logistic_regression_without_diabetes.csv', index_col=0),
    'neural_network': pd.read_csv('results/feature_importances_neural_network_without_diabetes.csv', index_col=0),
}

# %%
from util.functions import plot_feature_importances
plot_feature_importances(feature_importances)
